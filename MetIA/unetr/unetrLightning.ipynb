# %%
from networks.unetr import UNETR
#!pip install -r requirements.txt -f https://download.pytorch.org/whl/torch_stable.html
model = UNETR.load_from_checkpoint("/home/aurelien/Documents/Segmentation Métastases cérébrales et méningiomes par IA/UNETR/metastase_IA/RunTest1/checkpoints/checkpoint-epoch=0019-val_loss=1.777.ckpt")
#model.eval()
#y_hat = model("/home/aurelien/Documents/Segmentation Métastases cérébrales et méningiomes par IA/UNETR/metastase_IA/nifti_dataset/202207102/image.nii.gz")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 3
#       1 from networks.unetr import UNETR
#       2 #!pip install -r requirements.txt -f https://download.pytorch.org/whl/torch_stable.html
# ----> 3 model = UNETR.load_from_checkpoint("/home/aurelien/Documents/Segmentation Métastases cérébrales et méningiomes par IA/UNETR/metastase_IA/RunTest1/checkpoints/checkpoint-epoch=0019-val_loss=1.777.ckpt")
#       4 #model.eval()
#       5 #y_hat = model("/home/aurelien/Documents/Segmentation Métastases cérébrales et méningiomes par IA/UNETR/metastase_IA/nifti_dataset/202207102/image.nii.gz")
#
# File ~/anaconda3/envs/Tensorflow/lib/python3.9/site-packages/pytorch_lightning/core/saving.py:137, in ModelIO.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#      57 @classmethod
#      58 def load_from_checkpoint(
# ...
