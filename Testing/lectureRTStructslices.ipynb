# %%
from typing import List
import pydicom
from pydicom.dataset import Dataset
from io import BytesIO
import os 
import nibabel as nib
import numpy as np
import torch
from rt_utils import RTStructBuilder

# %%
rtstruct_path = "/Users/romain/Documents/P_R_O_J_E_C_T_S/IRM-Project/mbiaDataDownloads/DATA_VERITE_TERRAIN/META/"

# %%
def load_dicom_datasets(dicom_folder_path: str) -> List[Dataset]:
    """
    Charge tous les fichiers DICOM d'un dossier donné en datasets pydicom.
    """
    dicom_datasets = []
    for filename in os.listdir(dicom_folder_path):
        if filename.endswith('.dcm'):
            file_path = os.path.join(dicom_folder_path, filename)
            try:
                ds = pydicom.dcmread(file_path)
                dicom_datasets.append(ds)
            except Exception as e:
                print(f"Erreur lors de la lecture du fichier DICOM {filename}: {e}")
                continue  # ou lever une exception selon les besoins de votre application

    if not dicom_datasets:
        raise Exception("Aucun fichier DICOM valide trouvé dans le dossier spécifié.")

    return dicom_datasets

rtstruct_file = load_dicom_datasets(rtstruct_path)
print(rtstruct_file[0])

rtstruct = rtstruct_file[0]
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 278
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.752.243.1.1.20230602094342956.1800.51115
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.1.2.100.8.40.1101.0
# (0002, 0013) Implementation Version Name         SH: 'DicomObjects.NET'
# (0002, 0100) Private Information Creator UID     UI: 1.2.826.0.1.3680043.1.2.100.8.40.1101.0
# (0002, 0102) Private Information                 OB: b'DicomObjects.NET'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0012) Instance Creation Date              DA: '20230602'
# (0008, 0013) Instance Creation Time              TM: '094342.000000'
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.752.243.1.1.20230602094342956.1800.51115
# (0008, 0020) Study Date                          DA: '20200615'
# (0008, 0021) Series Date                         DA: '20230602'
# (0008, 0030) Study Time                          TM: '182558.949000'
# (0008, 0031) Series Time                         TM: '094342.000000'
# (0008, 0050) Accession Number                    SH: 'S105650226'
# (0008, 0060) Modality                            CS: 'RTSTRUCT'
# (0008, 0070) Manufacturer                        LO: 'RaySearch Laboratories'
# (0008, 0080) Institution Name                    LO: ''
# (0008, 0090) Referring Physician's Name          PN: 'DR LESUEUR'
# (0008, 1030) Study Description                   LO: 'CRANE^NEURO'
# (0008, 103e) Series Description                  LO: 'RS: Unapproved Structure Set'
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'RayStation'
# (0010, 0010) Patient's Name                      PN: 'ROSE^ALAIN'
# (0010, 0020) Patient ID                          LO: '201705956'
# (0010, 0030) Patient's Birth Date                DA: '19570815'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '12.0.0.932 (Dicom Export)'
# (0020, 000d) Study Instance UID                  UI: 1.2.250.1.38.2.1.14.1.33232.565022
# (0020, 000e) Series Instance UID                 UI: 1.2.752.243.1.1.20230602094342956.1800.51115.1
# (0020, 0010) Study ID                            SH: '2634678'
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.18.141255.2.20200615182559194.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (3006, 0002) Structure Set Label                 SH: 'RS: Unapproved'
# (3006, 0008) Structure Set Date                  DA: '20230602'
# (3006, 0009) Structure Set Time                  TM: '094342.000000'
# (3006, 0010)  Referenced Frame of Reference Sequence  1 item(s) ----
#    (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.18.141255.2.20200615182559194.0.0.0
#    (3006, 0012)  RT Referenced Study Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.2.250.1.38.2.1.14.1.33232.565022
#       (3006, 0014)  RT Referenced Series Sequence  1 item(s) ----
#          (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.18.141255.2020061518322745276199652.0.0.0
#          (3006, 0016)  Contour Image Sequence  208 item(s) ----
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371795957199841
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371797528199843
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371797672799845
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371798566799847
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371798876999849
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837181141299851
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837181991599853
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837182264499855
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837182508199857
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837182576199859
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837183010299861
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837184597899865
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371887933199867
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371888640899869
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371888988299871
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371889476499873
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371890781599875
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371891364699877
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371892704399879
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371893306099881
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371894543299899
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371896066899901
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371896465099903
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837191398599911
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371983261699937
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371983299699939
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371987041299941
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371988034599945
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371988650799947
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371988960699949
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371991318999951
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371994599699953
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371994622699955
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371995125799957
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371996915499959
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518371998872199961
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372069853299963
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372070359399965
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372074541499967
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372075395599979
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372077148299991
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372081870099995
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372089449900015
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372091485600021
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372097983000023
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837211676200027
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.20200615183721269200025
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837212992000029
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372158334900031
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372166260900033
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372168133600035
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372170129700037
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372173964800051
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372177578300053
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372182809500055
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372183567100057
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372195886500059
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372197242500061
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372198067200063
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372198356100065
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372246015600077
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372257015400079
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372261733300081
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372268914200083
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372269998000085
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372271396400087
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372272677100089
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372274388000091
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372292236400097
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372294133600099
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372296033000101
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372297591300103
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372330299600105
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372346473800131
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372355258000145
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372356407800149
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372358154700151
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372361157100153
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372372148500155
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372382466200165
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372390945000167
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372393399000169
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372395386600173
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372397681500189
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372428064400191
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372440684200193
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372442412800195
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372449845400197
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372450742800199
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372455108300201
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372468964100203
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372474511500205
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372484089200207
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372485665300209
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372493140700211
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372496169600213
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372516629700215
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372529396700217
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372532154000219
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372539671300221
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372539947900223
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372545892800225
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372556733600227
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372564471600229
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372571327500253
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372580706600265
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372591787700267
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372598971000271
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372627230300275
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372633366500277
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372634030400279
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372639563400281
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372643053300283
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837264556300273
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372648673500289
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372655592700291
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372656293300293
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372667049700295
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372690436900297
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372692506800299
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372699831100301
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372715414600303
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372722379200305
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372723096800307
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372729717000313
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372745856100321
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372746593500323
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372746644500325
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372753293600327
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372758309500329
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372781365300331
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372814605700337
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372821492900339
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372827377300341
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372830468900343
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372835771600345
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372836165200347
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372837104300349
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837283834800333
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372845533500351
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837284562700335
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372850400000353
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372876067300355
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372920346300363
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372921867300365
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372929329100367
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372929649600369
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372931407100371
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372939798400373
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372943447200375
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372947739600377
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837295463700357
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372964849200379
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837299704300359
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837299788700361
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373013120700387
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373014782800389
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373014981600391
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373016434900393
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373017981500395
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373032457900397
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373033616100399
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373034610900401
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837303925100381
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373046573800403
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837305742600383
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837307189000385
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373085392300405
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373088669100407
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373096099100409
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373096336800411
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373099487300413
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373112713900421
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373117831300423
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837312067800417
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373123097700425
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373127454400427
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837314583000419
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.20200615183731494000415
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373166701100429
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373170024100431
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373177609000433
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373179092900435
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373182081500437
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373182640000439
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373188711400441
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373192941400443
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373211901500449
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373213210800451
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373251126200453
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837325455000447
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373255570200455
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373262546200457
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373264874300459
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373269139500461
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373269274100463
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373281281600465
#             ---------
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.20200615183732838000445
#             ---------
# ...
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372639563400281
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '21'
#       (3006, 0048) Contour Number                      IS: '0'
#       (3006, 0050) Contour Data                        DS: Array of 63 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372633366500277
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '20'
#       (3006, 0048) Contour Number                      IS: '1'
#       (3006, 0050) Contour Data                        DS: Array of 60 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372643053300283
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '18'
#       (3006, 0048) Contour Number                      IS: '2'
#       (3006, 0050) Contour Data                        DS: Array of 54 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372648673500289
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '18'
#       (3006, 0048) Contour Number                      IS: '3'
#       (3006, 0050) Contour Data                        DS: Array of 54 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518372656293300293
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '22'
#       (3006, 0048) Contour Number                      IS: '4'
#       (3006, 0050) Contour Data                        DS: Array of 66 elements
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: '17'
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [255, 0, 0]
#    (3006, 0040)  Contour Sequence  19 item(s) ----
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373013120700387
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '31'
#       (3006, 0048) Contour Number                      IS: '0'
#       (3006, 0050) Contour Data                        DS: Array of 93 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373016434900393
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '38'
#       (3006, 0048) Contour Number                      IS: '1'
#       (3006, 0050) Contour Data                        DS: Array of 114 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373014782800389
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '48'
#       (3006, 0048) Contour Number                      IS: '2'
#       (3006, 0050) Contour Data                        DS: Array of 144 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373017981500395
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '48'
#       (3006, 0048) Contour Number                      IS: '3'
#       (3006, 0050) Contour Data                        DS: Array of 144 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373033616100399
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '62'
#       (3006, 0048) Contour Number                      IS: '4'
#       (3006, 0050) Contour Data                        DS: Array of 186 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373032457900397
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '64'
#       (3006, 0048) Contour Number                      IS: '5'
#       (3006, 0050) Contour Data                        DS: Array of 192 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373034610900401
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '53'
#       (3006, 0048) Contour Number                      IS: '6'
#       (3006, 0050) Contour Data                        DS: Array of 159 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373046573800403
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '68'
#       (3006, 0048) Contour Number                      IS: '7'
#       (3006, 0050) Contour Data                        DS: Array of 204 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373085392300405
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '70'
#       (3006, 0048) Contour Number                      IS: '8'
#       (3006, 0050) Contour Data                        DS: Array of 210 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837314583000419
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '72'
#       (3006, 0048) Contour Number                      IS: '9'
#       (3006, 0050) Contour Data                        DS: Array of 216 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373088669100407
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '60'
#       (3006, 0048) Contour Number                      IS: '10'
#       (3006, 0050) Contour Data                        DS: Array of 180 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373096336800411
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '68'
#       (3006, 0048) Contour Number                      IS: '11'
#       (3006, 0050) Contour Data                        DS: Array of 204 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373096099100409
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '64'
#       (3006, 0048) Contour Number                      IS: '12'
#       (3006, 0050) Contour Data                        DS: Array of 192 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.202006151837312067800417
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '60'
#       (3006, 0048) Contour Number                      IS: '13'
#       (3006, 0050) Contour Data                        DS: Array of 180 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373099487300413
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '58'
#       (3006, 0048) Contour Number                      IS: '14'
#       (3006, 0050) Contour Data                        DS: Array of 174 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.20200615183731494000415
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '52'
#       (3006, 0048) Contour Number                      IS: '15'
#       (3006, 0050) Contour Data                        DS: Array of 156 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373112713900421
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '47'
#       (3006, 0048) Contour Number                      IS: '16'
#       (3006, 0050) Contour Data                        DS: Array of 141 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373123097700425
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '42'
#       (3006, 0048) Contour Number                      IS: '17'
#       (3006, 0050) Contour Data                        DS: Array of 126 elements
#       ---------
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.18.141255.2020061518373117831300423
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#       (3006, 0046) Number of Contour Points            IS: '37'
#       (3006, 0048) Contour Number                      IS: '18'
#       (3006, 0050) Contour Data                        DS: Array of 111 elements
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: '19'
#    ---------
# (3006, 0080)  RT ROI Observations Sequence  6 item(s) ----
#    (3006, 0082) Observation Number                  IS: '1'
#    (3006, 0084) Referenced ROI Number               IS: '13'
#    (3006, 0085) ROI Observation Label               SH: 'GTV 1'
#    (3006, 00a4) RT ROI Interpreted Type             CS: 'GTV'
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
#    (3006, 0082) Observation Number                  IS: '2'
#    (3006, 0084) Referenced ROI Number               IS: '14'
#    (3006, 0085) ROI Observation Label               SH: 'GTV2'
#    (3006, 00a4) RT ROI Interpreted Type             CS: 'GTV'
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
#    (3006, 0082) Observation Number                  IS: '3'
#    (3006, 0084) Referenced ROI Number               IS: '15'
#    (3006, 0085) ROI Observation Label               SH: 'GTV3'
#    (3006, 00a4) RT ROI Interpreted Type             CS: 'GTV'
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
#    (3006, 0082) Observation Number                  IS: '4'
#    (3006, 0084) Referenced ROI Number               IS: '16'
#    (3006, 0085) ROI Observation Label               SH: 'GTV4'
#    (3006, 00a4) RT ROI Interpreted Type             CS: 'GTV'
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
#    (3006, 0082) Observation Number                  IS: '5'
#    (3006, 0084) Referenced ROI Number               IS: '17'
#    (3006, 0085) ROI Observation Label               SH: 'GTV 5'
#    (3006, 00a4) RT ROI Interpreted Type             CS: 'GTV'
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
#    (3006, 0082) Observation Number                  IS: '6'
#    (3006, 0084) Referenced ROI Number               IS: '19'
#    (3006, 0085) ROI Observation Label               SH: 'gtv6'
#    (3006, 00a4) RT ROI Interpreted Type             CS: 'GTV'
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
# (300e, 0002) Approval Status                     CS: 'UNAPPROVED'

# %%
print(type(rtstruct))
# Out:
# <class 'pydicom.dataset.FileDataset'>

# %% [markdown]
# # Récupérer les diamètres et les volumes des rois

# %%
import os
import pydicom
import numpy as np
from shapely.geometry import Polygon
from dicompylercore import dicomparser

# Charger le fichier DICOM RTStruct
rtstruct_path = "/Users/romain/Documents/P_R_O_J_E_C_T_S/IRM-Project/mbiaDataDownloads/DATA_VERITE_TERRAIN/META/RS1.2.752.243.1.1.20230602094342956.1800.51115.dcm"
dicoms_path = "/Users/romain/Documents/P_R_O_J_E_C_T_S/IRM-Project/mbiaDataDownloads/DATA_VERITE_TERRAIN/RM/IRM"

# Charger les images de la série DICOM
dicom_files = [os.path.join(dicoms_path, f) for f in os.listdir(dicoms_path) if f.endswith('.dcm')]
dicom_series = [pydicom.dcmread(f) for f in dicom_files]
dicom_series.sort(key=lambda x: int(x.InstanceNumber))

# Extraire les informations de PixelSpacing et SliceThickness
pixel_spacing = dicom_series[0].PixelSpacing
slice_thickness = dicom_series[0].SliceThickness

# Charger le fichier RTStruct avec dicompyler-core
rtstruct = dicomparser.DicomParser(rtstruct_path)

# Extraire les structures
structures = rtstruct.GetStructures()

# Fonction pour calculer le diamètre d'un ROI
def calculate_diameter(contour):
    max_distance = 0
    for i in range(len(contour)):
        for j in range(i + 1, len(contour)):
            distance = np.linalg.norm(np.array(contour[i]) - np.array(contour[j]))
            if distance > max_distance:
                max_distance = distance
    return max_distance

# Fonction pour calculer le volume d'un ROI
def calculate_volume(coords, thickness):
    volume = 0
    for z in coords.keys():
        contours = coords[z]
        for contour in contours:
            polygon = Polygon(contour['data'])
            volume += polygon.area * thickness
    return volume / 1000  # Convertir en cm³

# Parcourir les structures et extraire les informations
for roi_number, roi_data in structures.items():
    roi_name = roi_data['name']
    print(f"ROI: {roi_name}")
    
    # Obtenir les coordonnées des contours
    coords = rtstruct.GetStructureCoordinates(roi_number)
    
    # Calculer le volume
    thickness = dicomparser.DicomParser.CalculatePlaneThickness(rtstruct, coords)
    volume = calculate_volume(coords, thickness)
    
    # Calculer le diamètre maximal
    contours = []
    for plane in coords.values():
        for contour in plane:
            contours.append(contour['data'])
    diameters = [calculate_diameter(contour) for contour in contours]
    
    # Obtenir les slices de début et de fin
    start_slices = [contour[0][2] for contour in contours if contour]
    end_slices = [contour[-1][2] for contour in contours if contour]

    print(f"  Diamètre max: {max(diameters):.2f} mm")
    print(f"  Volume: {volume:.2f} cm³")
    print(f"  Slice de début: {min(start_slices)}")
    print(f"  Slice de fin: {max(end_slices)}")
# Out:
# ROI: GTV 1
#   Diamètre max: 6.20 mm
#   Volume: 0.14 cm³
#   Slice de début: 47.77951
#   Slice de fin: 53.77951
# ROI: GTV2
#   Diamètre max: 3.96 mm
#   Volume: 0.05 cm³
#   Slice de début: 56.77951
#   Slice de fin: 60.77951
# ROI: GTV3
#   Diamètre max: 7.35 mm
#   Volume: 0.18 cm³
#   Slice de début: 12.77951
#   Slice de fin: 18.77951
# ROI: GTV4
#   Diamètre max: 5.49 mm
#   Volume: 0.11 cm³
#   Slice de début: 12.77951
#   Slice de fin: 17.77951
# ROI: GTV 5
#   Diamètre max: 4.69 mm
#   Volume: 0.08 cm³
#   Slice de début: -12.22049
#   Slice de fin: -8.220492
# ROI: gtv6
#   Diamètre max: 20.11 mm
#   Volume: 2.85 cm³
#   Slice de début: 35.77951
#   Slice de fin: 53.77951

# %% [markdown]
# # Pipeline fonctionnel OMG

# %%
import os
import pydicom
import numpy as np
from shapely.geometry import Polygon
from dicompylercore import dicomparser

# Charger le fichier DICOM RTStruct
rtstruct_path = "/Users/romain/Documents/P_R_O_J_E_C_T_S/IRM-Project/mbiaDataDownloads/DATA_VERITE_TERRAIN/META/RS1.2.752.243.1.1.20230602094342956.1800.51115.dcm"
dicoms_path = "/Users/romain/Documents/P_R_O_J_E_C_T_S/IRM-Project/mbiaDataDownloads/DATA_VERITE_TERRAIN/RM/IRM"

# Charger les images de la série DICOM
dicom_files = [os.path.join(dicoms_path, f) for f in os.listdir(dicoms_path) if f.endswith('.dcm')]
dicom_series = [pydicom.dcmread(f) for f in dicom_files]
dicom_series.sort(key=lambda x: int(x.InstanceNumber))

# Extraire les informations de PixelSpacing et SliceThickness
pixel_spacing = dicom_series[0].PixelSpacing
slice_thickness = dicom_series[0].SliceThickness

# Créer une map des positions de slices à leurs indices
slice_positions = {round(dcm.ImagePositionPatient[2], 2): i+1 for i, dcm in enumerate(dicom_series)}

# Charger le fichier RTStruct avec dicompyler-core
rtstruct = dicomparser.DicomParser(rtstruct_path)

# Extraire les structures
structures = rtstruct.GetStructures()

# Fonction pour calculer le diamètre d'un ROI
def calculate_diameter(contour):
    max_distance = 0
    for i in range(len(contour)):
        for j in range(i + 1, len(contour)):
            distance = np.linalg.norm(np.array(contour[i]) - np.array(contour[j]))
            if distance > max_distance:
                max_distance = distance
    return max_distance

# Fonction pour calculer le volume d'un ROI
def calculate_volume(coords, thickness):
    volume = 0
    for z in coords.keys():
        contours = coords[z]
        for contour in contours:
            polygon = Polygon(contour['data'])
            volume += polygon.area * thickness
    return volume / 1000  # Convertir en cm³

# Parcourir les structures et extraire les informations
for roi_number, roi_data in structures.items():
    roi_name = roi_data['name']
    print(f"ROI: {roi_name}")
    
    # Obtenir les coordonnées des contours
    coords = rtstruct.GetStructureCoordinates(roi_number)
    
    # Calculer le volume
    thickness = dicomparser.DicomParser.CalculatePlaneThickness(rtstruct, coords)
    volume = calculate_volume(coords, thickness)
    
    # Calculer le diamètre maximal
    contours = []
    contour_slice_indices = []
    for plane in coords.values():
        for contour in plane:
            contours.append(contour['data'])
            z_pos = round(contour['data'][0][2], 2)
            if z_pos in slice_positions:
                contour_slice_indices.append(slice_positions[z_pos])
    
    diameters = [calculate_diameter(contour) for contour in contours]
    nb_dicoms = len(dicom_series)
    # Obtenir les slices de début et de fin
    start_slice = nb_dicoms - max(contour_slice_indices) if contour_slice_indices else None
    end_slice = nb_dicoms - min(contour_slice_indices) if contour_slice_indices else None
    
    print(f"  Diamètre max: {max(diameters):.2f} mm")
    print(f"  Volume: {volume:.2f} cm³")
    print(f"  Slice de début: {start_slice}")
    print(f"  Slice de fin: {end_slice}")
# Out:
# ROI: GTV 1
#   Diamètre max: 6.20 mm
#   Volume: 0.14 cm³
#   Slice de début: 30
#   Slice de fin: 36
# ROI: GTV2
#   Diamètre max: 3.96 mm
#   Volume: 0.05 cm³
#   Slice de début: 23
#   Slice de fin: 27
# ROI: GTV3
#   Diamètre max: 7.35 mm
#   Volume: 0.18 cm³
#   Slice de début: 65
#   Slice de fin: 71
# ROI: GTV4
#   Diamètre max: 5.49 mm
#   Volume: 0.11 cm³
#   Slice de début: 66
#   Slice de fin: 71
# ROI: GTV 5
#   Diamètre max: 4.69 mm
#   Volume: 0.08 cm³
#   Slice de début: 92
#   Slice de fin: 96
# ROI: gtv6
#   Diamètre max: 20.11 mm
#   Volume: 2.85 cm³
#   Slice de début: 30
#   Slice de fin: 48

# %%
print(len(dicom_series))
# Out:
# 208

# %% [markdown]
# # Version API (ça marche !!!!)

# %%
import os
import pydicom
import numpy as np
from shapely.geometry import Polygon
from dicompylercore import dicomparser

def extract_roi_info(rtstruct, dicom_series):

    dicom_series.sort(key=lambda x: int(x.InstanceNumber))
    
    # Extraire les informations de PixelSpacing et SliceThickness
    pixel_spacing = dicom_series[0].PixelSpacing
    slice_thickness = dicom_series[0].SliceThickness

    # Créer une map des positions de slices à leurs indices
    slice_positions = {round(dcm.ImagePositionPatient[2], 2): i+1 for i, dcm in enumerate(dicom_series)}

    # Charger le fichier RTStruct avec dicompyler-core
    rtstruct = dicomparser.DicomParser(rtstruct)

    # Extraire les structures
    structures = rtstruct.GetStructures()

    # Fonction pour calculer le diamètre d'un ROI
    def calculate_diameter(contour):
        max_distance = 0
        for i in range(len(contour)):
            for j in range(i + 1, len(contour)):
                distance = np.linalg.norm(np.array(contour[i]) - np.array(contour[j]))
                if distance > max_distance:
                    max_distance = distance
        return max_distance

    # Fonction pour calculer le volume d'un ROI
    def calculate_volume(coords, thickness):
        volume = 0
        for z in coords.keys():
            contours = coords[z]
            for contour in contours:
                polygon = Polygon(contour['data'])
                volume += polygon.area * thickness
        return volume / 1000  # Convertir en cm³

    # Initialiser le dictionnaire de résultats
    roi_info = {}

    # Parcourir les structures et extraire les informations
    for roi_number, roi_data in structures.items():
        roi_name = roi_data['name']
        
        # Obtenir les coordonnées des contours
        coords = rtstruct.GetStructureCoordinates(roi_number)
        
        # Calculer le volume
        thickness = dicomparser.DicomParser.CalculatePlaneThickness(rtstruct, coords)
        volume = calculate_volume(coords, thickness)
        
        # Calculer le diamètre maximal
        contours = []
        contour_slice_indices = []
        for plane in coords.values():
            for contour in plane:
                contours.append(contour['data'])
                z_pos = round(contour['data'][0][2], 2)
                if z_pos in slice_positions:
                    contour_slice_indices.append(slice_positions[z_pos])
        
        diameters = [calculate_diameter(contour) for contour in contours]
        nb_dicoms = len(dicom_series)
        
        # Obtenir les slices de début et de fin
        start_slice = nb_dicoms - max(contour_slice_indices) if contour_slice_indices else None
        end_slice = nb_dicoms - min(contour_slice_indices) if contour_slice_indices else None

        # Ajouter les informations au dictionnaire
        roi_info[roi_name] = {
            "diameter_max": max(diameters),
            "volume_cm3": volume,
            "start_slice": start_slice,
            "end_slice": end_slice
        }
    
    return roi_info

###########################################################################################################################
# Simulation de rtstruct et dicoms chargés en mémoire en objet pydicom :
def load_dicom_datasets(dicom_folder_path: str) -> List[Dataset]:
    """
    Charge tous les fichiers DICOM d'un dossier donné en datasets pydicom.
    """
    dicom_datasets = []
    for filename in os.listdir(dicom_folder_path):
        if filename.endswith('.dcm'):
            file_path = os.path.join(dicom_folder_path, filename)
            try:
                ds = pydicom.dcmread(file_path)
                dicom_datasets.append(ds)
            except Exception as e:
                print(f"Erreur lors de la lecture du fichier DICOM {filename}: {e}")
                continue  # ou lever une exception selon les besoins de votre application

    if not dicom_datasets:
        raise Exception("Aucun fichier DICOM valide trouvé dans le dossier spécifié.")

    return dicom_datasets
rtstruct_path = "/Users/romain/Documents/P_R_O_J_E_C_T_S/IRM-Project/mbiaDataDownloads/DATA_VERITE_TERRAIN/META/"
dicom_files = load_dicom_datasets(dicoms_path)
rtstruct_files = load_dicom_datasets(rtstruct_path)
rtstruct = rtstruct_files[0]

print("type de rtstruct : ", type(rtstruct))
print("type de dicom_files", type(dicom_files)," ", type(dicom_files[0]))
###########################################################################################################################

roi_info = extract_roi_info(rtstruct, dicom_files)
print(roi_info)
# Out:
# type de rtstruct :  <class 'pydicom.dataset.FileDataset'>
# type de dicom_files <class 'list'>   <class 'pydicom.dataset.FileDataset'>
# {'GTV 1': {'diameter_max': 6.195562862894834, 'volume_cm3': 0.13796970097221614, 'start_slice': 30, 'end_slice': 36}, 'GTV2': {'diameter_max': 3.963352447342527, 'volume_cm3': 0.052886430403313006, 'start_slice': 23, 'end_slice': 27}, 'GTV3': {'diameter_max': 7.348493565303027, 'volume_cm3': 0.1795430703734, 'start_slice': 65, 'end_slice': 71}, 'GTV4': {'diameter_max': 5.488227596774759, 'volume_cm3': 0.10696379318934995, 'start_slice': 66, 'end_slice': 71}, 'GTV 5': {'diameter_max': 4.6931767726455815, 'volume_cm3': 0.0793605851773, 'start_slice': 92, 'end_slice': 96}, 'gtv6': {'diameter_max': 20.10715011343477, 'volume_cm3': 2.8540769060405506, 'start_slice': 30, 'end_slice': 48}}
